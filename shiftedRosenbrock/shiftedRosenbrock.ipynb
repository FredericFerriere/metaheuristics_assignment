# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
import math
import time
import functionToOptimise as fun

# %%
class myCallback:
    def __init__(self):
        self.mxEvals = []
    def evaluate(self, x, *args):
        self.mxEvals.append(x)

# %% [markdown]
# # Dimension 50

# %%
f = fun.shiftedRosenbrock
low = -100
high = 100
my_dim = 50

np.random.seed(1234)
x_init = np.random.uniform(low=low, high=high, size=(my_dim))
cback = myCallback()
startTime = time.time()
sol50 = minimize(f, x_init, method='CG', args=(my_dim,), callback = cback.evaluate, 
                options = {'disp':False, 'maxiter':1000, 'gtol':1e-2, 'norm': np.inf, 'eps':1e-4})
runTime = time.time() - startTime
print('message: {}'.format(sol50.message))
print('function value: {:.2f}'.format(sol50.fun))
print('true minimum: {}'.format(fun.fbias[2]))
print('number of iterations: {}'.format(sol50.nit))
print('Computational time: {:.2f} s'.format(runTime))
# Out:
# message: Optimization terminated successfully.
# function value: 390.00
# true minimum: 390.0
# number of iterations: 669
# Computational time: 0.69 s

# %%
zoomIter = 20
plt.plot([i for i in range(zoomIter, len(cback.mxEvals))], [f(cback.mxEvals[i], my_dim) for i in range(zoomIter, len(cback.mxEvals))])
plt.xlabel('Iteration Number')
plt.ylabel('Function value')
plt.title('Function value as a function of iteration number')
plt.savefig('convergenceCurve_dim_' + str(my_dim))

# %% [markdown]
# # Dimension 500

# %%
f = fun.shiftedRosenbrock
low = -100
high = 100
my_dim = 500

np.random.seed(1234)
x_init = np.random.uniform(low=low, high=high, size=(my_dim))
cback = myCallback()
startTime = time.time()
sol500 = minimize(f, x_init, method='CG', args=(my_dim,), callback = cback.evaluate, 
                options = {'disp':False, 'maxiter':10000, 'gtol':1e-2, 'norm': np.inf, 'eps':1e-4})
runTime = time.time() - startTime
print('message: {}'.format(sol500.message))
print('function value: {:.2f}'.format(sol500.fun))
print('true minimum: {}'.format(fun.fbias[2]))
print('number of iterations: {}'.format(sol500.nit))
print('Computational time: {:.2f} s'.format(runTime))
# Out:
# message: Optimization terminated successfully.
# function value: 390.01
# true minimum: 390.0
# number of iterations: 5638
# Computational time: 72.53 s

# %%
zoomIter = 50
plt.plot([i for i in range(zoomIter, len(cback.mxEvals))], [f(cback.mxEvals[i], my_dim) for i in range(zoomIter, len(cback.mxEvals))])
plt.xlabel('Iteration Number')
plt.ylabel('Function value')
plt.title('Function value as a function of iteration number')
plt.savefig('convergenceCurve_dim_' + str(my_dim))

# %%
print('Solution dimension 50')
print(sol50.x)
# Out:
# Solution dimension 50
# [-75.42768287 -35.73190424 -57.59585991  38.90961773  52.2474431
#  -30.36127289  50.69055707  49.79840618 -71.15539366 -30.78391729
#  -43.00119761 -20.08836538  71.52700753  48.01970408 -46.02794067
#   -8.16369143 -40.97587939 -13.82759207  35.81632055  57.13753933
#   58.58513201 -17.41256691  27.28752895 -62.56260846 -28.81716102
#  -86.52887749  48.29238229  -7.58217093 -82.15988564 -72.07912856
#   82.24611465  19.58439243 -45.58599107  77.31325251 -12.61321144
#  -81.18471494  72.87789427  86.08191145  28.40035512  40.8527241
#   -2.04702689  33.44024165 -24.67160683 -17.82241928   2.58020866
#  -81.81450962  88.43215791 -34.29481204 -43.8833316   19.7244298 ]

# %%
print('Solution dimension 500')
print(sol500.x)
# Out:
# Solution dimension 500
# [-75.42767748 -35.73190034 -57.59586756  38.90960982  52.2474398
#  -30.36127274  50.69056777  49.79841346 -71.1553952  -30.78392309
